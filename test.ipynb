# %%
from utils.dataset import FLMNIST, mnist_data_split
from nodes.client import Client
from nodes.server import Server
from models.LeNet import LeNet

from torchvision import transforms
from torch.utils.data import DataLoader
from typing import List

import torch

# %%
dataset0 = FLMNIST(
        root="./datasets/",
        train=True,
        transform=transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1307,), (0.3081,))]),
        target_transform=None,
        download=False,
        data_ids=range(10000)
    )

dataset1 = FLMNIST(
        root="./datasets/",
        train=True,
        transform=transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1307,), (0.3081,))]),
        target_transform=None,
        download=False,
        data_ids=range(20000, 20300)
    )

# %%
test_iter = DataLoader(
    dataset=FLMNIST(
        root="./datasets/",
        train=False,
        transform=transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1307,), (0.3081,))]),
        target_transform=None,
        download=False,
        data_ids=range(10000)),
    batch_size=128,
    shuffle=True,
    num_workers=0
)

# %%
# initialize clients and server
model = LeNet()
model_structure = [0]
init_param = []
for param in model.parameters():
    model_structure.append(param.data.numel() + model_structure[-1])
    init_param += param.data.cpu().view(-1).tolist()

optimizer = torch.optim.Adam
loss_func = torch.nn.CrossEntropyLoss()

client0 = Client(dataset=dataset0, model_structure=model_structure, device='cuda')
client1 = Client(dataset=dataset1, model_structure=model_structure, device='cuda')

client0.set_weights(init_param)
client1.set_weights(init_param)

server = Server(model_structure=model_structure)

for epoch in range(1, 10):

    weight_list = []
    for cid, client in enumerate([client0, client1]):
        print("\ncid=%d:------"%cid)
        weight_list.append(
            client.local_train_step(model=model, loss_func=loss_func, optimizer=optimizer,
                            batch_size=128, num_workers=0, lr=0.01)
        )
        print("client accuracy=%.3f"%client.evaluate_accuracy(test_iter, model, 'cuda'))

    agg_weights = server.naive_aggregation(weight_list=weight_list)
    print("\nsever accuracy=%.3f"%server.evaluate_accuracy(test_iter, model, 'cuda'))
    
    for cid, client in enumerate([client0, client1]):
        client.set_weights(agg_weights.copy())
# Out:
# cid=0:------
# Parameter containing:
# tensor([ 0.0969,  0.0674,  0.0212,  0.0572,  0.0750, -0.0012,  0.0515,  0.0088,
#         -0.1032,  0.0494], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.1436, -0.1265,  0.0887,  0.0965,  0.1109, -0.0241,  0.0885,  0.0221,
#         -0.0038,  0.0416], device='cuda:0', requires_grad=True)
# client accuracy=0.240
#
# cid=1:------
# Parameter containing:
# tensor([ 0.0969,  0.0674,  0.0212,  0.0572,  0.0750, -0.0012,  0.0515,  0.0088,
#         -0.1032,  0.0494], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.1004,  0.0698,  0.0070,  0.0550,  0.0751, -0.0118,  0.0487,  0.0015,
#         -0.1067,  0.0539], device='cuda:0', requires_grad=True)
# client accuracy=0.098
#
# sever accuracy=0.129
#
# cid=0:------
# Parameter containing:
# tensor([ 0.1220, -0.0284,  0.0478,  0.0757,  0.0930, -0.0179,  0.0686,  0.0118,
#         -0.0552,  0.0477], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.6727, -0.3977,  0.1392,  0.1624,  0.1823,  0.0434,  0.1622, -0.2675,
#         -0.0629,  0.0051], device='cuda:0', requires_grad=True)
# client accuracy=0.615
#
# cid=1:------
# Parameter containing:
# tensor([ 0.1220, -0.0284,  0.0478,  0.0757,  0.0930, -0.0179,  0.0686,  0.0118,
#         -0.0552,  0.0477], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.1467, -0.0555,  0.0451,  0.0925,  0.1081, -0.0275,  0.0823, -0.0026,
#         -0.0785,  0.0352], device='cuda:0', requires_grad=True)
# client accuracy=0.137
#
# sever accuracy=0.395
#
# cid=0:------
# Parameter containing:
# tensor([ 0.4097, -0.2266,  0.0922,  0.1275,  0.1452,  0.0079,  0.1223, -0.1350,
#         -0.0707,  0.0201], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.8360, -0.4204, -0.0156,  0.0016,  0.2320, -0.0185,  0.0950, -0.2692,
#         -0.2310,  0.0206], device='cuda:0', requires_grad=True)
# client accuracy=0.859
#
# cid=1:------
# Parameter containing:
# tensor([ 0.4097, -0.2266,  0.0922,  0.1275,  0.1452,  0.0079,  0.1223, -0.1350,
#         -0.0707,  0.0201], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.4121, -0.2546,  0.0926,  0.1374,  0.1658, -0.0171,  0.1509, -0.1197,
#         -0.1002,  0.0342], device='cuda:0', requires_grad=True)
# client accuracy=0.501
#
# sever accuracy=0.727
#
# cid=0:------
# Parameter containing:
# tensor([ 0.6240, -0.3375,  0.0385,  0.0695,  0.1989, -0.0178,  0.1230, -0.1944,
#         -0.1656,  0.0274], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.9214, -0.4736, -0.0670,  0.0035,  0.2575, -0.0351,  0.1611, -0.2564,
#         -0.2534,  0.0695], device='cuda:0', requires_grad=True)
# client accuracy=0.912
#
# cid=1:------
# Parameter containing:
# tensor([ 0.6240, -0.3375,  0.0385,  0.0695,  0.1989, -0.0178,  0.1230, -0.1944,
#         -0.1656,  0.0274], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.6540, -0.3506,  0.0456,  0.0675,  0.2163, -0.0228,  0.1224, -0.2012,
#         -0.1695,  0.0253], device='cuda:0', requires_grad=True)
# client accuracy=0.727
#
# sever accuracy=0.863
#
# cid=0:------
# Parameter containing:
# tensor([ 0.7877, -0.4121, -0.0107,  0.0355,  0.2369, -0.0289,  0.1417, -0.2288,
#         -0.2114,  0.0474], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.9775, -0.4753, -0.0377,  0.0115,  0.2854, -0.0224,  0.1626, -0.2446,
#         -0.2373,  0.0618], device='cuda:0', requires_grad=True)
# client accuracy=0.931
#
# cid=1:------
# Parameter containing:
# tensor([ 0.7877, -0.4121, -0.0107,  0.0355,  0.2369, -0.0289,  0.1417, -0.2288,
#         -0.2114,  0.0474], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.8177, -0.4110, -0.0156,  0.0087,  0.2407, -0.0201,  0.1202, -0.2289,
#         -0.2330,  0.0490], device='cuda:0', requires_grad=True)
# client accuracy=0.849
#
# sever accuracy=0.911
#
# cid=0:------
# Parameter containing:
# tensor([ 0.8976, -0.4432, -0.0267,  0.0101,  0.2630, -0.0213,  0.1414, -0.2368,
#         -0.2352,  0.0554], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 1.0487e+00, -4.9669e-01, -4.2677e-02,  1.0297e-03,  2.6774e-01,
#         -1.9281e-02,  1.9662e-01, -2.4411e-01, -2.4229e-01,  6.3630e-02],
#        device='cuda:0', requires_grad=True)
# client accuracy=0.902
#
# cid=1:------
# Parameter containing:
# tensor([ 0.8976, -0.4432, -0.0267,  0.0101,  0.2630, -0.0213,  0.1414, -0.2368,
#         -0.2352,  0.0554], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 0.9000, -0.4221, -0.0332, -0.0139,  0.2594, -0.0204,  0.1415, -0.2403,
#         -0.2340,  0.0600], device='cuda:0', requires_grad=True)
# client accuracy=0.885
#
# sever accuracy=0.915
#
# cid=0:------
# Parameter containing:
# tensor([ 0.9744, -0.4594, -0.0380, -0.0064,  0.2636, -0.0198,  0.1691, -0.2422,
#         -0.2381,  0.0618], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 1.0501, -0.5053, -0.0669, -0.0023,  0.2566, -0.0215,  0.2017, -0.2518,
#         -0.2330,  0.0775], device='cuda:0', requires_grad=True)
# client accuracy=0.951
#
# cid=1:------
# Parameter containing:
# tensor([ 0.9744, -0.4594, -0.0380, -0.0064,  0.2636, -0.0198,  0.1691, -0.2422,
#         -0.2381,  0.0618], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 9.6006e-01, -4.3285e-01, -2.1287e-02, -7.1289e-03,  2.5711e-01,
#          5.0515e-05,  1.5472e-01, -2.4213e-01, -2.4260e-01,  8.1482e-02],
#        device='cuda:0', requires_grad=True)
# client accuracy=0.921
#
# sever accuracy=0.948
#
# cid=0:------
# Parameter containing:
# tensor([ 1.0051, -0.4691, -0.0441, -0.0047,  0.2569, -0.0107,  0.1782, -0.2470,
#         -0.2378,  0.0795], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 1.0568, -0.5070, -0.0592,  0.0076,  0.2540, -0.0278,  0.1790, -0.2643,
#         -0.2340,  0.0876], device='cuda:0', requires_grad=True)
# client accuracy=0.950
#
# cid=1:------
# Parameter containing:
# tensor([ 1.0051, -0.4691, -0.0441, -0.0047,  0.2569, -0.0107,  0.1782, -0.2470,
#         -0.2378,  0.0795], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 1.0199, -0.4628, -0.0289, -0.0146,  0.2597, -0.0116,  0.1581, -0.2486,
#         -0.2441,  0.0847], device='cuda:0', requires_grad=True)
# client accuracy=0.938
#
# sever accuracy=0.958
#
# cid=0:------
# Parameter containing:
# tensor([ 1.0383, -0.4849, -0.0441, -0.0035,  0.2569, -0.0197,  0.1685, -0.2564,
#         -0.2390,  0.0861], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 1.0595, -0.5134, -0.0540, -0.0052,  0.2562, -0.0218,  0.2128, -0.2603,
#         -0.2415,  0.0898], device='cuda:0', requires_grad=True)
# client accuracy=0.956
#
# cid=1:------
# Parameter containing:
# tensor([ 1.0383, -0.4849, -0.0441, -0.0035,  0.2569, -0.0197,  0.1685, -0.2564,
#         -0.2390,  0.0861], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([ 1.0443, -0.4765, -0.0621, -0.0175,  0.2604, -0.0248,  0.1601, -0.2576,
#         -0.2513,  0.0874], device='cuda:0', requires_grad=True)
# client accuracy=0.945
#
# sever accuracy=0.963
